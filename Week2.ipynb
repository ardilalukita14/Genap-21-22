# %% [markdown]
# <a href="https://colab.research.google.com/github/ardilalukita14/PCVK-Genap-21-22/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PRAKTIKUM**
# **Penggunaan Numpy dan OpenCV serta Pengenalan Aplikasi-aplikasi Pengolahan Citra**

# %% [markdown]
# Import folder yang ada di Drive Anda dengan cara sebagai berikut.

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang sudah ada. Contohnya pada kode program di bawah file image dengan nama kitten01.jpg ak--'an dibuka untuk diproses lebih lanjut.

# %% [markdown]
# Hasil nya berupa output gambar yang sudah di plot dengan matplotlib untuk mengetahui ukuran panjang dan lebar dari gambar tersebut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten02.jpg')
plt.imshow(img)                           #perhatikan hasilnya adalah citra dengan channel warna BGR

# %% [markdown]
# OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red) Tampilkan nilai pixel dan image.

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)     #konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil.

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten02.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’.

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024
# Citra.

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik.

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2.tiff', img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))         #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2.

# %%
#perhatikan koordinat titik pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
#perhatikan koordinat titik pt1 dan pt2
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program.

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32
# Berikut.

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32.

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut.

# %%
pts = vertices.reshape((-1,1,2))  # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # **TUGAS**

# %% [markdown]
# **1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!**

# %%
# menampilkan band Red-Green
plt.imshow(r)

# %% [markdown]
# **2. Tampilkan image baris ke 10-100, kolom 10-100!**

# %%
cropped_image = img3[10:100, 10:100]
plt.imshow(cropped_image)

# %% [markdown]
# **3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!**

# %%
cropped_image2 = img3[5:30]
plt.imshow(cropped_image2)

# %%
# Band blue, green dan red masng-masing disimpan pada variabel b,g,r
b = cropped_image2[...,0]  # blue channel
g = cropped_image2[...,1]  # green channel
r = cropped_image2[...,2]  # red channel

# %%
plt.imshow(g)

# %% [markdown]
# **4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!**

# %%
img_cat = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten02.jpg')
plt.imshow(img_cat)

# %%
img_cat2 = img_cat
img_cat3 = cv.cvtColor(img_cat, cv.COLOR_BGR2RGB)     #konversi channel BGR -> RGB
plt.imshow(img_cat3)

# %%
cv.rectangle(img_cat3, pt1=(480,220), pt2=(350,400), color=(0,255,255), thickness=8)
cv.rectangle(img_cat3, pt1=(1000,30), pt2=(650,380), color=(255,69,0), thickness=8)
cv.rectangle(img_cat3, pt1=(320,390), pt2=(250,470), color=(255,255,0), thickness=8)
cv.rectangle(img_cat3, pt1=(700,410), pt2=(580,550), color=(255,0,19), thickness=8)
cv.rectangle(img_cat3, pt1=(790,210), pt2=(700,280), color=(199,21,133), thickness=8)
plt.imshow(img_cat3)

# %% [markdown]
# **5. Tampilkan image dengan posisi terbalik!**

# %%
img_cat4 = cv.flip(cv.cvtColor(img_cat3, 0),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2.tiff', img_buah4)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))         #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img_cat4)

# %% [markdown]
# ## **Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :**

# %% [markdown]
# **6. Buat rectangle dan circle pada bagian wajah dari image kitten!**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img_new = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img_new)                           #perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img_new2 = img_new
img_new3 = cv.cvtColor(img_new, cv.COLOR_BGR2RGB)     #konversi channel BGR -> RGB
plt.imshow(img_new3)

# %%
cv.rectangle(img_new3, pt1=(180,1), pt2=(75,95), color=(0,255,0), thickness=1)
cv.circle(img_new3, center=(130,52), radius=50, color=(255,0,0), thickness=1)
plt.imshow(img_new3)

# %% [markdown]
# **7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!**

# %%
img_new4 = img_new
img_new4 = cv.cvtColor(img_new, cv.COLOR_BGR2RGB)     #konversi channel BGR -> RGB
plt.imshow(img_new4)

# %%
# Band blue, green dan red masng-masing disimpan pada variabel b,g,r
b = img_new4[...,0]  # blue channel
g = img_new4[...,1]  # green channel
r = img_new4[...,2]  # red channel

# %%
cv.rectangle(img_new4, pt1=(20,200), pt2=(3,215), color=(10,100,215), thickness=2)
plt.imshow(img_new4)

# %%
img_new4 = plt.imshow(b)
